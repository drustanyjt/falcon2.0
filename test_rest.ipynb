# %%
import requests

# %%
url = "https://httpbin.org/get"
url = "https://wikidata.demo.openlinksw.com/sparql"
r = requests.get(url)

# %%
from pprint import pprint
pprint(r.content)
# Out:
# (b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n<meta charset="utf-8" />\n<m'
#  b'eta name="viewport"  content="width=device-width, initial-scale=1, shrink-to'
#  b'-fit=no" />\n<meta name="Copyright" content="Copyright &#169; 2023 OpenLi'
#  b'nk Software" />\n<meta name="Keywords"  content="OpenLink Virtuoso Sparql'
#  b'" />\n<title>OpenLink Virtuoso SPARQL Query Editor</title>\n\n<link rel="ic'
#  b'on" href="/favicon.ico?v=1" sizes="any" />\n<link rel="icon" href="/favic'
#  b'on/favicon.svg?v=1" type="image/svg+xml" />\n<link rel="apple-touch-icon"'
#  b' href="/favicon/apple-touch-icon-180x180.png?v=1" />\n<link rel="manifest'
#  b'" href="/favicon/manifest.webmanifest?v=1" />\n<link rel="stylesheet" hre'
#  b'f="https://cdnjs.cloudflare.com/ajax/libs/bootstrap/5.2.3/css/bootstrap.min.'
#  b'css" integrity="sha512-SbiR/eusphKoMVVXysTKG/7VseWii+Y3FdHrt0EpKgpToZeemhqHe'
#  b'ZeLWLhJutz/2ut2Vw1uQEj2MbRF+TVBUA==" crossorigin="anonymous" />\n</head>\n'
# ...
